# %% [markdown]
# The histogram gives an overall idea bout the intensity distribution of an image. It is a plot with pixel values ranging from 0 to 255 in X-axis and corresponding number of pixels in the image on the y-axis.
#
# It is just a different way of understanding the image. we get intuition about the contrast brightness, intensity distribution of that image. almost all image procesing tools today procide features on historgram.
#
# Studying the historgam properly will tell if the image has been properly exposed whether the lighting is harsh or flat, and what adjustments will wrok best. It will not improve the computer skills, but also the photography skills.
#
# A RGB historgam results when the computer scans through each of these RGB brightness values and counts how many are at each level from 0 through 255.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tones
#
# the region where mostof the brightness values are prsent is called the "tonal range". The tonal range can vary drastically from iamge to image. There is no one ideal historgam that one must mimic, but it should be representant vie of the toanl range in the scene. for example:- a coastal region has very few midtones, but meany shadows and highlights.
#
# Conditions of ordinary and even lighting when combined with a properly exposed subject will usually produce a historgram which peaks in the center, gradualy tapering off into the shadows and highlights.
#
# ## High and low-key images
#
# almost all cameras will produce midtone-centric histograms when in an automatic exposure mode. the distribution of the peaks also depends on the tonal range of the subject.
#
# Images where most of the tones occur in the shadows are called "low key" , whereas with 'highkey" images most of the tones are in the highlights.
#
#
# before the photo has been taken, it is useful to assess whether or not the subject matter qualifies as high or low key. Since cameras measure reflected as opposed to incident light, theya re unable to assess the subjets's absolute brightness. To circumvent this limitation, cameras contain sophisticated algorithms. With this, the averate brightness is placed in the midtones. but with high and low key scenes, the phogotgrapher would have to manually adjust the exposure relative to what the camera would do automatically. A good rule si that you will need to manually adjust the exposure whenever the average brightness in the image appears brighte or darker than the midtnoes.
#
# Improper exposure may result in clipped highlights.
#
# most digital cmeras are better at reproducing the low key scnes since htye prevent any region from becong solid white regardless of dark the rest of the image is. High ke scenes on the other hand often prodcue images hwihc are significantly underesposed.
#
# Histogram is a good tool for knowing whtere clipping has actually occured since we can readily see when the highlights sare pusehd to teh edge of the chart. some clipping is accepted when there are images with refrlections.
#
#
# ## Contrast.
#
# It is the measure o the diffference between the light and deark areas ofa a scene. Broad histograms show images with significant contrast. narrow histograms reflect less contrast and may appear flat or dull.
#
# contrast can also vary for different regiions iwth ing the same image due to both the sbject matter and lighting.
