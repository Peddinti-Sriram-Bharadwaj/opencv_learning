# %% [markdown]
# ## accessing and modifying pixel values

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('./sample_imgs/rasenshuriken.jpeg')

# %%
# accessing pixel intensities at a coordinate

px = img[100,100]
print(px)
# Out:
# [94 79 87]

# %%
# accessing only one channel pixel 
blue = img[100,100,0]
print(blue)
# Out:
# 94

# %% [markdown]
# it is more efficient to use numpy for this kind of operations

# %%
img.item(10,10,2)
# Out:
# 129

# %%
img[10,10,2] = 100
img.item(10,10,2)
# Out:
# 100

# %% [markdown]
# ## accesssing image properties

# %%
print(img.shape)
# Out:
# (168, 300, 3)

# %%
img.size
# Out:
# 151200

# %%
img.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# ## Image region of interest

# %%
rasenshuriken = img[:, :]

# %% [markdown]
# ## splitting and merging of image channels

# %%
b, g, r = cv2.split(img)

# %%
img = cv2.merge((b,g,r))

# %%
b = img[:,:0]

# %%
img[:,:,2] = 0

# %% [markdown]
# ## making borders for images (padding)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
BLUE = [255,0,0]

img1 = cv2.imread('./sample_imgs/sharingan.png')

# %%
replicate = cv2.copyMakeBorder(img1, 10,10,10,10, cv2.BORDER_REPLICATE)

# %%
reflect = cv2.copyMakeBorder(img1, 10,10,10,10, cv2.BORDER_REFLECT)

# %%
reflect101 = cv2.copyMakeBorder(img1, 10, 10, 10, 10, cv2.BORDER_REFLECT_101)

# %%
wrap = cv2.copyMakeBorder(img1, 10,10,10,10, cv2.BORDER_WRAP)

# %%
constant = cv2.copyMakeBorder(img1, 10,10,10,10, cv2.BORDER_CONSTANT, value = BLUE)

# %%
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

plt.show()
